# %% [raw]
# ---
# title: "rtichoke"
# author: "Uriah Finkel"
# format: html
# execute:
#     enabled: true
# ---

# %% [markdown]
# ## rtichoke
# This is a nice document for rtichoke

# %%
import requests
import pandas as pd


r = requests.post(
   "http://127.0.0.1:6706/roc_curve_list", 
   data=None,
   json=None
)

rtichoke_curve_list = r.json()



rtichoke_curve_list["reference_data"] = pd.DataFrame.from_dict(rtichoke_curve_list["reference_data"]) 
rtichoke_curve_list["performance_data_ready_for_curve"] = pd.DataFrame.from_dict(rtichoke_curve_list["performance_data_ready_for_curve"]) 

import os
os.getcwd()
# Out:
# 'C:\\Users\\CRI_user'
