# %% [markdown]
# # Example usage
#
# To use `rtichoke` in a project:

# %%
import rtichoke

print(rtichoke.__version__)
# Out:
# 0.1.0

# %%
import pandas as pd
# from rtichoke.rtichoke_curves.exported_functions import create_plotly_curve
# from rtichoke.rtichoke_curves.roc import create_roc_curve
# from rtichoke.rtichoke_curves.roc import plot_roc_curve
# from rtichoke.rtichoke_curves.lift import create_lift_curve
# from rtichoke.rtichoke_curves.gains import create_gains_curve
# from rtichoke.rtichoke_curves.precision_recall import create_precision_recall_curve
# from rtichoke.rtichoke_curves.performance_data import prepare_performance_data
# from rtichoke.rtichoke_curves.calibration import create_calibration_curve
# from rtichoke.rtichoke_curves.send_post_request_to_r_rtichoke import send_requests_to_rtichoke_r
import pandas as pd
import json
import requests
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import numpy as np
print(pd.__version__)

import plotly

import rtichoke

print( 1 + 2)
# Out:
# 1.5.2
# 3

# %%
import pandas as pd
# from rtichoke.rtichoke_curves.exported_functions import create_plotly_curve
# from rtichoke.rtichoke_curves.roc import create_roc_curve
# from rtichoke.rtichoke_curves.roc import plot_roc_curve
# from rtichoke.rtichoke_curves.lift import create_lift_curve
# from rtichoke.rtichoke_curves.gains import create_gains_curve
# from rtichoke.rtichoke_curves.precision_recall import create_precision_recall_curve
# from rtichoke.rtichoke_curves.performance_data import prepare_performance_data
# from rtichoke.rtichoke_curves.calibration import create_calibration_curve
# from rtichoke.rtichoke_curves.send_post_request_to_r_rtichoke import send_requests_to_rtichoke_r
import pandas as pd
import json
import requests
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import numpy as np
print(pd.__version__)

import plotly

import rtichoke
dir()
lr = LogisticRegression()
x = np.arange(10).reshape(-1, 1)
y = np.array([0, 1, 0, 0, 1, 1, 1, 0, 0, 1])

x_test = np.arange(7).reshape(-1, 1)
y_test = np.array([1, 0, 1, 0, 1, 0, 0])

model = LogisticRegression(solver='liblinear', random_state=0)
lasso = LogisticRegression(solver='liblinear', penalty="l1", random_state=0)

model.fit(x, y)
lasso.fit(x_test, y_test)


# Performance Data

performance_data = rtichoke.prepare_performance_data(
    probs = {'Logistic Regression' :  model.predict_proba(x)[:,1].tolist()},
    reals = {'Logistic Regression' : y.tolist()},
    url_api = "http://127.0.0.1:6214/"
)

performance_data
# Out:
# 1.5.2
# dict_keys(['probability_threshold', 'TP', 'TN', 'FN', 'FP', 'sensitivity', 'FPR', 'specificity', 'PPV', 'NPV', 'lift', 'predicted_positives', 'NB', 'ppcr'])
#      probability_threshold  TP  TN  FN  FP  sensitivity  FPR  specificity  \
# 0                     0.00   5   0   0   5          1.0  1.0          0.0
# 1                     0.01   5   0   0   5          1.0  1.0          0.0
# 2                     0.02   5   0   0   5          1.0  1.0          0.0
# 3                     0.03   5   0   0   5          1.0  1.0          0.0
# 4                     0.04   5   0   0   5          1.0  1.0          0.0
# ..                     ...  ..  ..  ..  ..          ...  ...          ...
# 96                    0.96   0   5   5   0          0.0  0.0          1.0
# 97                    0.97   0   5   5   0          0.0  0.0          1.0
# 98                    0.98   0   5   5   0          0.0  0.0          1.0
# 99                    0.99   0   5   5   0          0.0  0.0          1.0
# 100                   1.00   0   5   5   0          0.0  0.0          1.0
#
#      PPV  NPV  lift  predicted_positives      NB  ppcr
# 0    0.5  NaN   1.0                   10  0.5000   1.0
# 1    0.5  NaN   1.0                   10  0.4949   1.0
# 2    0.5  NaN   1.0                   10  0.4898   1.0
# 3    0.5  NaN   1.0                   10  0.4845   1.0
# 4    0.5  NaN   1.0                   10  0.4792   1.0
# ..   ...  ...   ...                  ...     ...   ...
# 96   NaN  0.5   NaN                    0  0.0000   0.0
# 97   NaN  0.5   NaN                    0  0.0000   0.0
# 98   NaN  0.5   NaN                    0  0.0000   0.0
# 99   NaN  0.5   NaN                    0  0.0000   0.0
# 100  NaN  0.5   NaN                    0     NaN   0.0
#
# [101 rows x 14 columns]

# %%
import pandas as pd
# from rtichoke.rtichoke_curves.exported_functions import create_plotly_curve
# from rtichoke.rtichoke_curves.roc import create_roc_curve
# from rtichoke.rtichoke_curves.roc import plot_roc_curve
# from rtichoke.rtichoke_curves.lift import create_lift_curve
# from rtichoke.rtichoke_curves.gains import create_gains_curve
# from rtichoke.rtichoke_curves.precision_recall import create_precision_recall_curve
# from rtichoke.rtichoke_curves.performance_data import prepare_performance_data
# from rtichoke.rtichoke_curves.calibration import create_calibration_curve
# from rtichoke.rtichoke_curves.send_post_request_to_r_rtichoke import send_requests_to_rtichoke_r
import pandas as pd
import json
import requests
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import numpy as np
print(pd.__version__)

import plotly

import rtichoke
dir()
lr = LogisticRegression()
x = np.arange(10).reshape(-1, 1)
y = np.array([0, 1, 0, 0, 1, 1, 1, 0, 0, 1])

x_test = np.arange(7).reshape(-1, 1)
y_test = np.array([1, 0, 1, 0, 1, 0, 0])

model = LogisticRegression(solver='liblinear', random_state=0)
lasso = LogisticRegression(solver='liblinear', penalty="l1", random_state=0)

model.fit(x, y)
lasso.fit(x_test, y_test)


# Performance Data

performance_data = rtichoke.prepare_performance_data(
    probs = {'Logistic Regression' :  model.predict_proba(x)[:,1].tolist()},
    reals = {'Logistic Regression' : y.tolist()},
    url_api = "http://127.0.0.1:3198/"
)

# performance_data
# Out:
# 1.5.2
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\ProgramData\Miniconda3\envs\rtichoke\lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\ProgramData\Miniconda3\envs\rtichoke\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File c:\ProgramData\Miniconda3\envs\rtichoke\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File c:\ProgramData\Miniconda3\envs\rtichoke\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[13], line 40
#      35 lasso.fit(x_test, y_test)
#      38 # Performance Data
# ---> 40 performance_data = rtichoke.prepare_performance_data(
#      41     probs = {'Logistic Regression' :  model.predict_proba(x)[:,1].tolist()},
#      42     reals = {'Logistic Regression' : y.tolist()},
#      43     url_api = "http://127.0.0.1:3198/"
#      44 )
#      46 # performance_data
#
# File ~\Documents\rtichoke_python\rtichoke\src\rtichoke\performance_data\performance_data.py:16, in prepare_performance_data(probs, reals, stratified_by, url_api)
#       5 def prepare_performance_data(probs, reals, stratified_by = "probability_threshold", url_api = "http://localhost:4242/"):
#       7     r = send_requests_to_rtichoke_r(
#       8            dictionary_to_send = {
#       9                 "probs": probs,
#    (...)
#      14            endpoint = "prepare_performance_data"
#      15         )
# ---> 16     print(r.json()[0].keys())
#      17     performance_data = pd.DataFrame(r.json(), columns=list(r.json()[0].keys()))
#      18     return performance_data
#
# File c:\ProgramData\Miniconda3\envs\rtichoke\lib\site-packages\requests\models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
